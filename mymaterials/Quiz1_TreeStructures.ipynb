# %% [markdown]
# # Q(1)

# %% [markdown]
# ![Screen Shot 2024-01-24 at 7.49.10 PM.png](attachment:8eba1bf0-e1c8-4c02-b9fb-6ce8189da174.png)

# %% [markdown]
# # Q(2)

# %% [raw]
# This is the tree to my "csci_1070_course" directory. Due to a lot of reorganzing clutter and duplicates of my files, I now have 2 items inside this directory. The first one is a local folder called 'mymaterials', containing all my assignments, notes, and quizzes from this course section. The second item is a git-repo clone from my professors' public GitHub, made for this course. In there are weekly folders containing lecture notes and assignements.

# %% [markdown]
# # Q(3)

# %%
# Have conditional logic to print "<month> is my birthday" if the month in the iteration is your birth month.

# %%
months = ["January","February","March","April","May","June","July","August","September","October","November","December"]

birthday_month = (months[6])

print (birthday_month + " is my birthday month.")
# Out:
# July is my birthday month.
